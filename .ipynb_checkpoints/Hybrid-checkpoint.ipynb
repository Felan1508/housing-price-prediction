# %%
import pandas as pd
# Load the CSV file (replace 'your_file.csv' with the actual file name)
df = pd.read_csv("mogi_tphcm_houses_cleaned_filtered_v2.csv")

# %%
import numpy as np
df["Price_USD_log"] = np.log1p(df["Price_USD"])

# %%
df = df[df['Price_USD'] <= 800000]  # Houses ≤ $800K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64070 entries, 12 to 94815
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   64070 non-null  object
#  1   Price                  64070 non-null  object
#  2   Location               64070 non-null  object
#  3   Bedrooms               64070 non-null  int64
#  4   Bathrooms              64070 non-null  int64
#  5   Area                   64070 non-null  int64
#  6   Price_Numeric          64070 non-null  int64
#  7   Price_per_m2           64070 non-null  float64
#  8   Distance_km_to_centre  64070 non-null  float64
#  9   Population             64070 non-null  int64
#  10  Price_USD              64070 non-null  float64
#  11  Price_USD_log          64070 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 6.4+ MB

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Bathrooms'}>,
#         <Axes: title={'center': 'Area'}>],
#        [<Axes: title={'center': 'Price_Numeric'}>,
#         <Axes: title={'center': 'Price_per_m2'}>,
#         <Axes: title={'center': 'Distance_km_to_centre'}>],
#        [<Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'Price_USD'}>,
#         <Axes: title={'center': 'Price_USD_log'}>]], dtype=object)

# %%
lowest_row = df.nlargest(10, "Distance_km_to_centre")
print(lowest_row)
# Out:
#                                                     Name           Price  \
# 3739   Bán nhà gần Bến Phà Bình Khánh -Cần giờ 198,4 ...  4 tỷ 400 triệu
# 47272  Bán Nhanh Căn Nhà Thái Đẹp, Đ.Đào Cử, TT Cần T...            5 tỷ
# 3125   Nhà Mặt Tiền đường 79, Tân Phú Trung, Củ Chi, ...  5 tỷ 600 triệu
# 4468   Bán xưởng mini DT 150m2. Tân Phú Trung. Giá 4,...  4 tỷ 800 triệu
# 4469   Bán nhà 200m2 Mặt tiền TL15. Tân thạnh đông. G...            7 tỷ
# 4470   Bán Nhà DT 135m2. Mt đường Lưu Khai Hồng. Thị ...  4 tỷ 400 triệu
# 4471   Bán Nhà Lầu Hoàn Công DT 100m2. Thị trấn Củ Ch...  4 tỷ 500 triệu
# 4472   Bán Nhà 1 trệt 1 Lầu DT 130m2. Tân Phú Trung. ...  4 tỷ 100 triệu
# 22338  BÁN NHÀ MT 158M2 chỉ 7 tỷ nguyễn kim cương củ chi            7 tỷ
# 24655             NHÀ+ xưởng 10*20 thổ cư SỔ HỒNG  riêng  6 tỷ 500 triệu
#
#                    Location  Bedrooms  Bathrooms  Area  Price_Numeric  \
# 3739   Huyện Cần Giờ, TPHCM         2          1   198     4400000000
# 47272  Huyện Cần Giờ, TPHCM         2          1    84     5000000000
# 3125    Huyện Củ Chi, TPHCM         2          2   145     5600000000
# 4468    Huyện Củ Chi, TPHCM         4          2   150     4800000000
# 567           Quận Gò Vấp, TPHCM         2          2   200     8500000000
# 569         Quận Bình Tân, TPHCM         6          3   200    45000000000
#
#      Price_per_m2  Distance_km_to_centre  Population     Price_USD  \
# 23    8793.356131               1.510718      196333  1.758671e+06
# 153   6643.869077               8.937515      784173  1.328774e+06
# 236   7620.908647               8.937515      784173  1.524182e+06
# 266   2012.701514              17.128503      542243  4.025403e+05
# 361   7425.500733               5.446668      147168  1.485100e+06
# 362   8793.356131               8.937515      784173  1.758671e+06
# 390   6155.349292               8.937515      784173  1.231070e+06
# 554   9770.395701               8.937515      784173  1.954079e+06
# 567   1660.967269               6.984046      663313  3.321935e+05
# 569   8793.356131               8.937515      784173  1.758671e+06
#
#      Price_USD_log
# 23       14.380070
# 153      14.099768
# 236      14.236969
# 266      12.905553
# 361      14.210993
# 362      14.380070
# 390      14.023395
# 554      14.485430
# 567      12.713476
# 569      14.380070

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load your dataset
X = df[['Bedrooms', 'Bathrooms', 'Area', 'Population', 'Distance_km_to_centre']]
y = df['Price_USD_log']  # Assuming log-transformed prices for stability

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train XGBoost model
xgb_model = xgb.XGBRegressor(
    n_estimators=500,  # Increase number of trees
    learning_rate=0.05,  # Reduce learning rate
    max_depth=7,  # Increase depth for more complex patterns
    subsample=0.8,  # Reduce overfitting
    colsample_bytree=0.8,
    objective='reg:squarederror'
)
xgb_model.fit(X_train, y_train)

# Get XGBoost predictions on training & test sets
xgb_train_preds = xgb_model.predict(X_train).reshape(-1, 1)
xgb_test_preds = xgb_model.predict(X_test).reshape(-1, 1)

# %%
# Build a simple neural network
nn_model = Sequential([
    Dense(64, activation='relu', input_shape=(1,)),  # Input: XGBoost predictions
    Dense(32, activation='relu'),
    Dense(1)  # Output: Final house price prediction
])

# Compile the model
nn_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the neural network
nn_model.fit(xgb_train_preds, y_train, epochs=20, batch_size=32, validation_data=(xgb_test_preds, y_test))
# Out:
# Epoch 1/20
# 1602/1602 [==============================] - 2s 1ms/step - loss: 1.8298 - mae: 0.4080 - val_loss: 0.0887 - val_mae: 0.2303
# Epoch 2/20
# 1602/1602 [==============================] - 2s 1ms/step - loss: 0.0723 - mae: 0.2099 - val_loss: 0.0870 - val_mae: 0.2350
# Epoch 3/20
# 1602/1602 [==============================] - 2s 1ms/step - loss: 0.0737 - mae: 0.2121 - val_loss: 0.0852 - val_mae: 0.2262
# Epoch 4/20
# 1602/1602 [==============================] - 2s 1ms/step - loss: 0.0745 - mae: 0.2133 - val_loss: 0.0852 - val_mae: 0.2315
# Epoch 5/20
# 1602/1602 [==============================] - 2s 1ms/step - loss: 0.0767 - mae: 0.2164 - val_loss: 0.0848 - val_mae: 0.2255
# Epoch 6/20
# 1602/1602 [==============================] - 2s 1ms/step - loss: 0.0754 - mae: 0.2143 - val_loss: 0.0824 - val_mae: 0.2233
# Epoch 7/20
# 1602/1602 [==============================] - 2s 965us/step - loss: 0.0751 - mae: 0.2136 - val_loss: 0.0820 - val_mae: 0.2237
# Epoch 8/20
# 1602/1602 [==============================] - 1s 916us/step - loss: 0.0756 - mae: 0.2145 - val_loss: 0.0898 - val_mae: 0.2311
# Epoch 9/20
# 1602/1602 [==============================] - 1s 916us/step - loss: 0.0759 - mae: 0.2150 - val_loss: 0.0831 - val_mae: 0.2264
# Epoch 10/20
# 1602/1602 [==============================] - 1s 923us/step - loss: 0.0758 - mae: 0.2145 - val_loss: 0.0853 - val_mae: 0.2255
# Epoch 11/20
# 1602/1602 [==============================] - 2s 936us/step - loss: 0.0757 - mae: 0.2142 - val_loss: 0.0838 - val_mae: 0.2240
# Epoch 12/20
# 1602/1602 [==============================] - 1s 926us/step - loss: 0.0747 - mae: 0.2129 - val_loss: 0.0856 - val_mae: 0.2258
# Epoch 13/20
# 1602/1602 [==============================] - 1s 921us/step - loss: 0.0753 - mae: 0.2138 - val_loss: 0.0846 - val_mae: 0.2246
# Epoch 14/20
# 1602/1602 [==============================] - 1s 929us/step - loss: 0.0747 - mae: 0.2125 - val_loss: 0.0836 - val_mae: 0.2271
# Epoch 15/20
# 1602/1602 [==============================] - 2s 967us/step - loss: 0.0755 - mae: 0.2137 - val_loss: 0.0824 - val_mae: 0.2243
# Epoch 16/20
# 1602/1602 [==============================] - 1s 921us/step - loss: 0.0754 - mae: 0.2136 - val_loss: 0.0821 - val_mae: 0.2229
# Epoch 17/20
# 1602/1602 [==============================] - 1s 929us/step - loss: 0.0748 - mae: 0.2126 - val_loss: 0.0858 - val_mae: 0.2258
# Epoch 18/20
# 1602/1602 [==============================] - 2s 976us/step - loss: 0.0748 - mae: 0.2124 - val_loss: 0.0821 - val_mae: 0.2231
# Epoch 19/20
# 1602/1602 [==============================] - 2s 951us/step - loss: 0.0749 - mae: 0.2129 - val_loss: 0.0855 - val_mae: 0.2255
# Epoch 20/20
# 1602/1602 [==============================] - 2s 952us/step - loss: 0.0745 - mae: 0.2119 - val_loss: 0.0841 - val_mae: 0.2238

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Get final predictions from NN
y_pred_log = nn_model.predict(xgb_test_preds)

# Convert back to original scale (if using log transform)
y_pred_actual = np.expm1(y_pred_log)
y_test_actual = np.expm1(y_test)

# Calculate metrics
mae = mean_absolute_error(y_test_actual, y_pred_actual)
mse = mean_squared_error(y_test_actual, y_pred_actual)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual, y_pred_actual)

# Print results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.4f}")
# Out:
# 401/401 [==============================] - 0s 491us/step
# Mean Absolute Error (MAE): 93083.73
# Mean Squared Error (MSE): 14505030324.14
# Root Mean Squared Error (RMSE): 120436.83
# R² Score: 0.5119

# %%
df.to_csv("mogi_tphcm_houses_cleaned_filtered_v2.csv", index=False)
